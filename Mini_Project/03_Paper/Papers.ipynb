# %% [markdown]
# -----------------------------------------------------------------------------
# # 1. 건물과 도로 각각 검출
# - Open Library : mmsegmentation, Segmentation models
# - https://github.com/open-mmlab/mmsegmentation
# - https://github.com/qubvel/segmentation_models
#
# ## DeeplabV3
# •  논문
# -  https://arxiv.org/pdf/1802.02611.pdf
#
# •  참고자료
# - https://blog.lunit.io/2018/07/02/deeplab-v3-encoder-decoder-with-atrous-separable-convolution-for-semantic-image-segmentation/
# - https://medium.com/hyunjulie/2편-두-접근의-접점-deeplab-v3-ef7316d4209d
#
# •  코드
# - https://github.com/bonlime/keras-deeplab-v3-plus
# - https://github.com/tensorflow/models/tree/master/research/deeplab
#
#
# ## HRNetV2
# •  논문
# - https://arxiv.org/abs/1908.07919v2
#
# •  참고자료
# - https://www.wenyanet.com/opensource/ko/605ed3b064a25d343d10ef8e.html
#
# •  코드
# - https://github.com/HRNet/HRNet-Semantic-Segmentation
#
#
# ## Segformer
# •  논문
# - https://arxiv.org/pdf/2105.15203.pdf
#
# •  참고자료
# - https://nuguziii.github.io/paper-review/PR-010/
# - https://github.com/dhkim0225/1day_1paper/issues/55
#
# •  코드
# - https://github.com/NVlabs/SegFormer
#
# ## SpaceNet 7
# •  발표자료
# - https://medium.com/the-downlinq/the-spacenet-7-multi-temporal-urban-development-challenge-announcing-the-winners-847a9a53004c
#
# •  참고자료
# - https://blog.si-analytics.ai/61
# - https://medium.com/the-downlinq/spacenet-7-results-arxiv-paper-and-winning-model-release-8da36df16aa5
#
# •  코드
# - https://github.com/SpaceNetChallenge/SpaceNet7_Multi-Temporal_Solutions
# -----------------------------------------------------------------------------
# # 2. 건물의 객체검출을 위한 학습
# - 위성 영상 분석의 목적은 시각적으로 향상된 분석결과를 제공
# - 건물간 ID를 부여할 수 있도록 독립된 객체로 분리하거나, 분리된 결과가 도출되어야 함
#
# ## SpaceNet 4
# •  참고자료
# - https://medium.com/the-downlinq/the-spacenet-challenge-off-nadir-buildings-introducing-the-winners-b60f2b700266
# - https://medium.com/the-downlinq/a-baseline-model-for-the-spacenet-4-off-nadir-building-detection-challenge-6b7983312b4b
#
# •  코드
# - https://github.com/SpaceNetChallenge/SpaceNet_Off_Nadir_Solutions
#
# Mask R-CNN
# •  논문
# - https://arxiv.org/abs/1703.06870
#
# •  참고자료
# - https://paperswithcode.com/paper/mask-r-cnn
# - https://herbwood.tistory.com/20
#
# •  코드
# - https://github.com/matterport/Mask_RCNN
#
#
# ## Polygonization and Mapping
# - Semantic segmentation 기반 폴리곤화
# - Instance Segmentation
# -----------------------------------------------------------------------------
